# %%
import tensorflow as tf
import os

# %%
import cv2

# %%
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
import imghdr

# %%
import numpy as np
import matplotlib as plt

# %%
data_dir='prospace_assignment'

# %%
import os
import tensorflow as tf
from PIL import Image

count = 0  # Global variable

def load_and_preprocess_image(file_path, target_size=(64, 64)):
    global count  # Access the global count variable
    # Load TIFF image using Pillow (PIL)
    image = Image.open(file_path)
    # Resize to target size and convert to RGB
    image = image.resize(target_size)
    image = image.convert("RGB")
    # Convert image to numpy array and normalize (you can use this when using tf)
    image_array = tf.keras.preprocessing.image.img_to_array(image)
    image_array = image_array / 255.0  # Normalize pixel values
    count += 1  # Increment count for each processed image
    print(f"Processed image {count}: {file_path}")
    return image_array

def load_tiff_dataset(directory):
    global count  # Declare 'count' as global
    file_paths = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.tif')]
    images = [load_and_preprocess_image(file) for file in file_paths]
    # Convert images to TensorFlow tensors
    images = [tf.convert_to_tensor(image) for image in images]
    dataset = tf.data.Dataset.from_tensor_slices(images)
    return dataset

# Example usage
data_directory = 'prospace_assignment'
dataset = load_tiff_dataset(data_directory)
# Out:
# Processed image 1: prospace_assignment\100_2022_10.tif
# Processed image 2: prospace_assignment\100_2022_11.tif
# Processed image 3: prospace_assignment\100_2022_4.tif
# Processed image 4: prospace_assignment\100_2022_5.tif
# Processed image 5: prospace_assignment\100_2022_6.tif
# Processed image 6: prospace_assignment\100_2022_7.tif
# Processed image 7: prospace_assignment\100_2022_8.tif
# Processed image 8: prospace_assignment\100_2022_9.tif
# Processed image 9: prospace_assignment\100_2023_0.tif
# Processed image 10: prospace_assignment\100_2023_1.tif
# Processed image 11: prospace_assignment\100_2023_2.tif
# Processed image 12: prospace_assignment\100_2023_3.tif
# Processed image 13: prospace_assignment\101_2022_10.tif
# Processed image 14: prospace_assignment\101_2022_11.tif
# Processed image 15: prospace_assignment\101_2022_4.tif
# Processed image 16: prospace_assignment\101_2022_5.tif
# Processed image 17: prospace_assignment\101_2022_6.tif
# Processed image 18: prospace_assignment\101_2022_7.tif
# Processed image 19: prospace_assignment\101_2022_8.tif
# Processed image 20: prospace_assignment\101_2022_9.tif
# Processed image 21: prospace_assignment\101_2023_0.tif
# Processed image 22: prospace_assignment\101_2023_1.tif
# Processed image 23: prospace_assignment\101_2023_2.tif
# Processed image 24: prospace_assignment\101_2023_3.tif
# Processed image 25: prospace_assignment\102_2022_10.tif
# Processed image 26: prospace_assignment\102_2022_11.tif
# Processed image 27: prospace_assignment\102_2022_4.tif
# Processed image 28: prospace_assignment\102_2022_5.tif
# Processed image 29: prospace_assignment\102_2022_6.tif
# Processed image 30: prospace_assignment\102_2022_7.tif
# Processed image 31: prospace_assignment\102_2022_8.tif
# Processed image 32: prospace_assignment\102_2022_9.tif
# Processed image 33: prospace_assignment\102_2023_0.tif
# Processed image 34: prospace_assignment\102_2023_1.tif
# Processed image 35: prospace_assignment\102_2023_2.tif
# Processed image 36: prospace_assignment\102_2023_3.tif
# Processed image 37: prospace_assignment\103_2022_10.tif
# Processed image 38: prospace_assignment\103_2022_11.tif
# Processed image 39: prospace_assignment\103_2022_4.tif
# Processed image 40: prospace_assignment\103_2022_5.tif
# Processed image 41: prospace_assignment\103_2022_6.tif
# Processed image 42: prospace_assignment\103_2022_7.tif
# Processed image 43: prospace_assignment\103_2022_8.tif
# Processed image 44: prospace_assignment\103_2022_9.tif
# Processed image 45: prospace_assignment\103_2023_0.tif
# Processed image 46: prospace_assignment\103_2023_1.tif
# Processed image 47: prospace_assignment\103_2023_2.tif
# Processed image 48: prospace_assignment\103_2023_3.tif
# Processed image 49: prospace_assignment\104_2022_10.tif
# Processed image 50: prospace_assignment\104_2022_11.tif
# Processed image 51: prospace_assignment\104_2022_4.tif
# Processed image 52: prospace_assignment\104_2022_5.tif
# Processed image 53: prospace_assignment\104_2022_6.tif
# Processed image 54: prospace_assignment\104_2022_7.tif
# Processed image 55: prospace_assignment\104_2022_8.tif
# Processed image 56: prospace_assignment\104_2022_9.tif
# Processed image 57: prospace_assignment\104_2023_0.tif
# Processed image 58: prospace_assignment\104_2023_1.tif
# Processed image 59: prospace_assignment\104_2023_2.tif
# Processed image 60: prospace_assignment\104_2023_3.tif
# Processed image 61: prospace_assignment\105_2022_10.tif
# Processed image 62: prospace_assignment\105_2022_11.tif
# Processed image 63: prospace_assignment\105_2022_4.tif
# Processed image 64: prospace_assignment\105_2022_5.tif
# Processed image 65: prospace_assignment\105_2022_6.tif
# Processed image 66: prospace_assignment\105_2022_7.tif
# Processed image 67: prospace_assignment\105_2022_8.tif
# Processed image 68: prospace_assignment\105_2022_9.tif
# Processed image 69: prospace_assignment\105_2023_0.tif
# Processed image 70: prospace_assignment\105_2023_1.tif
# Processed image 71: prospace_assignment\105_2023_2.tif
# Processed image 72: prospace_assignment\105_2023_3.tif
# Processed image 73: prospace_assignment\106_2022_10.tif
# Processed image 74: prospace_assignment\106_2022_11.tif
# Processed image 75: prospace_assignment\106_2022_4.tif
# Processed image 76: prospace_assignment\106_2022_5.tif
# Processed image 77: prospace_assignment\106_2022_6.tif
# Processed image 78: prospace_assignment\106_2022_7.tif
# Processed image 79: prospace_assignment\106_2022_8.tif
# Processed image 80: prospace_assignment\106_2022_9.tif
# Processed image 81: prospace_assignment\106_2023_0.tif
# Processed image 82: prospace_assignment\106_2023_1.tif
# Processed image 83: prospace_assignment\106_2023_2.tif
# Processed image 84: prospace_assignment\106_2023_3.tif
# Processed image 85: prospace_assignment\107_2022_10.tif
# Processed image 86: prospace_assignment\107_2022_11.tif
# Processed image 87: prospace_assignment\107_2022_4.tif
# Processed image 88: prospace_assignment\107_2022_5.tif
# Processed image 89: prospace_assignment\107_2022_6.tif
# Processed image 90: prospace_assignment\107_2022_7.tif
# Processed image 91: prospace_assignment\107_2022_8.tif
# Processed image 92: prospace_assignment\107_2022_9.tif
# Processed image 93: prospace_assignment\107_2023_0.tif
# Processed image 94: prospace_assignment\107_2023_1.tif
# Processed image 95: prospace_assignment\107_2023_2.tif
# Processed image 96: prospace_assignment\107_2023_3.tif
# Processed image 97: prospace_assignment\108_2022_10.tif
# Processed image 98: prospace_assignment\108_2022_11.tif
# Processed image 99: prospace_assignment\108_2022_4.tif
# Processed image 100: prospace_assignment\108_2022_5.tif
# Processed image 101: prospace_assignment\108_2022_6.tif
# Processed image 102: prospace_assignment\108_2022_7.tif
# Processed image 103: prospace_assignment\108_2022_8.tif
# Processed image 104: prospace_assignment\108_2022_9.tif
# Processed image 105: prospace_assignment\108_2023_0.tif
# Processed image 106: prospace_assignment\108_2023_1.tif
# Processed image 107: prospace_assignment\108_2023_2.tif
# Processed image 108: prospace_assignment\108_2023_3.tif
# Processed image 109: prospace_assignment\109_2022_10.tif
# Processed image 110: prospace_assignment\109_2022_11.tif
# Processed image 111: prospace_assignment\109_2022_4.tif
# Processed image 112: prospace_assignment\109_2022_5.tif
# Processed image 113: prospace_assignment\109_2022_6.tif
# Processed image 114: prospace_assignment\109_2022_7.tif
# Processed image 115: prospace_assignment\109_2022_8.tif
# Processed image 116: prospace_assignment\109_2022_9.tif
# Processed image 117: prospace_assignment\109_2023_0.tif
# Processed image 118: prospace_assignment\109_2023_1.tif
# Processed image 119: prospace_assignment\109_2023_2.tif
# Processed image 120: prospace_assignment\109_2023_3.tif
# Processed image 121: prospace_assignment\10_2022_10.tif
# Processed image 122: prospace_assignment\10_2022_11.tif
# Processed image 123: prospace_assignment\10_2022_4.tif
# Processed image 124: prospace_assignment\10_2022_5.tif
# Processed image 125: prospace_assignment\10_2022_6.tif
# Processed image 126: prospace_assignment\10_2022_7.tif
# Processed image 127: prospace_assignment\10_2022_8.tif
# Processed image 128: prospace_assignment\10_2022_9.tif
# Processed image 129: prospace_assignment\10_2023_0.tif
# Processed image 130: prospace_assignment\10_2023_1.tif
# Processed image 131: prospace_assignment\10_2023_2.tif
# Processed image 132: prospace_assignment\10_2023_3.tif
# Processed image 133: prospace_assignment\110_2022_10.tif
# Processed image 134: prospace_assignment\110_2022_11.tif
# Processed image 135: prospace_assignment\110_2022_4.tif
# Processed image 136: prospace_assignment\110_2022_5.tif
# Processed image 137: prospace_assignment\110_2022_6.tif
# Processed image 138: prospace_assignment\110_2022_7.tif
# Processed image 139: prospace_assignment\110_2022_8.tif
# Processed image 140: prospace_assignment\110_2022_9.tif
# Processed image 141: prospace_assignment\110_2023_0.tif
# Processed image 142: prospace_assignment\110_2023_1.tif
# Processed image 143: prospace_assignment\110_2023_2.tif
# Processed image 144: prospace_assignment\110_2023_3.tif
# Processed image 145: prospace_assignment\111_2022_10.tif
# Processed image 146: prospace_assignment\111_2022_11.tif
# Processed image 147: prospace_assignment\111_2022_4.tif
# Processed image 148: prospace_assignment\111_2022_5.tif
# Processed image 149: prospace_assignment\111_2022_6.tif
# Processed image 150: prospace_assignment\111_2022_7.tif
# Processed image 151: prospace_assignment\111_2022_8.tif
# Processed image 152: prospace_assignment\111_2022_9.tif
# Processed image 153: prospace_assignment\111_2023_0.tif
# Processed image 154: prospace_assignment\111_2023_1.tif
# Processed image 155: prospace_assignment\111_2023_2.tif
# Processed image 156: prospace_assignment\111_2023_3.tif
# Processed image 157: prospace_assignment\112_2022_10.tif
# Processed image 158: prospace_assignment\112_2022_11.tif
# Processed image 159: prospace_assignment\112_2022_4.tif
# Processed image 160: prospace_assignment\112_2022_5.tif
# Processed image 161: prospace_assignment\112_2022_6.tif
# Processed image 162: prospace_assignment\112_2022_7.tif
# Processed image 163: prospace_assignment\112_2022_8.tif
# Processed image 164: prospace_assignment\112_2022_9.tif
# Processed image 165: prospace_assignment\112_2023_0.tif
# Processed image 166: prospace_assignment\112_2023_1.tif
# Processed image 167: prospace_assignment\112_2023_2.tif
# Processed image 168: prospace_assignment\112_2023_3.tif
# Processed image 169: prospace_assignment\113_2022_10.tif
# Processed image 170: prospace_assignment\113_2022_11.tif
# Processed image 171: prospace_assignment\113_2022_4.tif
# Processed image 172: prospace_assignment\113_2022_5.tif
# Processed image 173: prospace_assignment\113_2022_6.tif
# Processed image 174: prospace_assignment\113_2022_7.tif
# Processed image 175: prospace_assignment\113_2022_8.tif
# Processed image 176: prospace_assignment\113_2022_9.tif
# Processed image 177: prospace_assignment\113_2023_0.tif
# Processed image 178: prospace_assignment\113_2023_1.tif
# Processed image 179: prospace_assignment\113_2023_2.tif
# Processed image 180: prospace_assignment\113_2023_3.tif
# Processed image 181: prospace_assignment\114_2022_10.tif
# Processed image 182: prospace_assignment\114_2022_11.tif
# Processed image 183: prospace_assignment\114_2022_4.tif
# Processed image 184: prospace_assignment\114_2022_5.tif
# Processed image 185: prospace_assignment\114_2022_6.tif
# Processed image 186: prospace_assignment\114_2022_7.tif
# Processed image 187: prospace_assignment\114_2022_8.tif
# Processed image 188: prospace_assignment\114_2022_9.tif
# Processed image 189: prospace_assignment\114_2023_0.tif
# Processed image 190: prospace_assignment\114_2023_1.tif
# Processed image 191: prospace_assignment\114_2023_2.tif
# Processed image 192: prospace_assignment\114_2023_3.tif
# Processed image 193: prospace_assignment\115_2022_10.tif
# Processed image 194: prospace_assignment\115_2022_11.tif
# Processed image 195: prospace_assignment\115_2022_4.tif
# Processed image 196: prospace_assignment\115_2022_5.tif
# Processed image 197: prospace_assignment\115_2022_6.tif
# Processed image 198: prospace_assignment\115_2022_7.tif
# Processed image 199: prospace_assignment\115_2022_8.tif
# Processed image 200: prospace_assignment\115_2022_9.tif
# Processed image 201: prospace_assignment\115_2023_0.tif
# Processed image 202: prospace_assignment\115_2023_1.tif
# Processed image 203: prospace_assignment\115_2023_2.tif
# Processed image 204: prospace_assignment\115_2023_3.tif
# Processed image 205: prospace_assignment\116_2022_10.tif
# Processed image 206: prospace_assignment\116_2022_11.tif
# Processed image 207: prospace_assignment\116_2022_4.tif
# Processed image 208: prospace_assignment\116_2022_5.tif
# Processed image 209: prospace_assignment\116_2022_6.tif
# Processed image 210: prospace_assignment\116_2022_7.tif
# Processed image 211: prospace_assignment\116_2022_8.tif
# Processed image 212: prospace_assignment\116_2022_9.tif
# Processed image 213: prospace_assignment\116_2023_0.tif
# Processed image 214: prospace_assignment\116_2023_1.tif
# Processed image 215: prospace_assignment\116_2023_2.tif
# Processed image 216: prospace_assignment\116_2023_3.tif
# Processed image 217: prospace_assignment\117_2022_10.tif
# Processed image 218: prospace_assignment\117_2022_11.tif
# Processed image 219: prospace_assignment\117_2022_4.tif
# Processed image 220: prospace_assignment\117_2022_5.tif
# Processed image 221: prospace_assignment\117_2022_6.tif
# Processed image 222: prospace_assignment\117_2022_7.tif
# Processed image 223: prospace_assignment\117_2022_8.tif
# Processed image 224: prospace_assignment\117_2022_9.tif
# Processed image 225: prospace_assignment\117_2023_0.tif
# Processed image 226: prospace_assignment\117_2023_1.tif
# Processed image 227: prospace_assignment\117_2023_2.tif
# Processed image 228: prospace_assignment\117_2023_3.tif
# Processed image 229: prospace_assignment\118_2022_10.tif
# Processed image 230: prospace_assignment\118_2022_11.tif
# Processed image 231: prospace_assignment\118_2022_4.tif
# Processed image 232: prospace_assignment\118_2022_5.tif
# Processed image 233: prospace_assignment\118_2022_6.tif
# Processed image 234: prospace_assignment\118_2022_7.tif
# Processed image 235: prospace_assignment\118_2022_8.tif
# Processed image 236: prospace_assignment\118_2022_9.tif
# Processed image 237: prospace_assignment\118_2023_0.tif
# Processed image 238: prospace_assignment\118_2023_1.tif
# Processed image 239: prospace_assignment\118_2023_2.tif
# Processed image 240: prospace_assignment\118_2023_3.tif
# Processed image 241: prospace_assignment\119_2022_10.tif
# Processed image 242: prospace_assignment\119_2022_11.tif
# Processed image 243: prospace_assignment\119_2022_4.tif
# Processed image 244: prospace_assignment\119_2022_5.tif
# Processed image 245: prospace_assignment\119_2022_6.tif
# Processed image 246: prospace_assignment\119_2022_7.tif
# Processed image 247: prospace_assignment\119_2022_8.tif
# Processed image 248: prospace_assignment\119_2022_9.tif
# Processed image 249: prospace_assignment\119_2023_0.tif
# Processed image 250: prospace_assignment\119_2023_1.tif
# Processed image 251: prospace_assignment\119_2023_2.tif
# Processed image 252: prospace_assignment\119_2023_3.tif
# Processed image 253: prospace_assignment\11_2022_10.tif
# Processed image 254: prospace_assignment\11_2022_11.tif
# Processed image 255: prospace_assignment\11_2022_4.tif
# Processed image 256: prospace_assignment\11_2022_5.tif
# Processed image 257: prospace_assignment\11_2022_6.tif
# Processed image 258: prospace_assignment\11_2022_7.tif
# Processed image 259: prospace_assignment\11_2022_8.tif
# Processed image 260: prospace_assignment\11_2022_9.tif
# Processed image 261: prospace_assignment\11_2023_0.tif
# Processed image 262: prospace_assignment\11_2023_1.tif
# Processed image 263: prospace_assignment\11_2023_2.tif
# Processed image 264: prospace_assignment\11_2023_3.tif
# Processed image 265: prospace_assignment\120_2022_10.tif
# Processed image 266: prospace_assignment\120_2022_11.tif
# Processed image 267: prospace_assignment\120_2022_4.tif
# Processed image 268: prospace_assignment\120_2022_5.tif
# Processed image 269: prospace_assignment\120_2022_6.tif
# Processed image 270: prospace_assignment\120_2022_7.tif
# Processed image 271: prospace_assignment\120_2022_8.tif
# Processed image 272: prospace_assignment\120_2022_9.tif
# Processed image 273: prospace_assignment\120_2023_0.tif
# Processed image 274: prospace_assignment\120_2023_1.tif
# Processed image 275: prospace_assignment\120_2023_2.tif
# Processed image 276: prospace_assignment\120_2023_3.tif
# Processed image 277: prospace_assignment\121_2022_10.tif
# Processed image 278: prospace_assignment\121_2022_11.tif
# Processed image 279: prospace_assignment\121_2022_4.tif
# Processed image 280: prospace_assignment\121_2022_5.tif
# Processed image 281: prospace_assignment\121_2022_6.tif
# Processed image 282: prospace_assignment\121_2022_7.tif
# Processed image 283: prospace_assignment\121_2022_8.tif
# Processed image 284: prospace_assignment\121_2022_9.tif
# Processed image 285: prospace_assignment\121_2023_0.tif
# Processed image 286: prospace_assignment\121_2023_1.tif
# Processed image 287: prospace_assignment\121_2023_2.tif
# Processed image 288: prospace_assignment\121_2023_3.tif
# Processed image 289: prospace_assignment\122_2022_10.tif
# Processed image 290: prospace_assignment\122_2022_11.tif
# Processed image 291: prospace_assignment\122_2022_4.tif
# Processed image 292: prospace_assignment\122_2022_5.tif
# Processed image 293: prospace_assignment\122_2022_6.tif
# Processed image 294: prospace_assignment\122_2022_7.tif
# Processed image 295: prospace_assignment\122_2022_8.tif
# Processed image 296: prospace_assignment\122_2022_9.tif
# Processed image 297: prospace_assignment\122_2023_0.tif
# Processed image 298: prospace_assignment\122_2023_1.tif
# Processed image 299: prospace_assignment\122_2023_2.tif
# Processed image 300: prospace_assignment\122_2023_3.tif
# Processed image 301: prospace_assignment\123_2022_10.tif
# Processed image 302: prospace_assignment\123_2022_11.tif
# Processed image 303: prospace_assignment\123_2022_4.tif
# Processed image 304: prospace_assignment\123_2022_5.tif
# Processed image 305: prospace_assignment\123_2022_6.tif
# Processed image 306: prospace_assignment\123_2022_7.tif
# Processed image 307: prospace_assignment\123_2022_8.tif
# Processed image 308: prospace_assignment\123_2022_9.tif
# Processed image 309: prospace_assignment\123_2023_0.tif
# Processed image 310: prospace_assignment\123_2023_1.tif
# Processed image 311: prospace_assignment\123_2023_2.tif
# Processed image 312: prospace_assignment\123_2023_3.tif
# Processed image 313: prospace_assignment\124_2022_10.tif
# Processed image 314: prospace_assignment\124_2022_11.tif
# Processed image 315: prospace_assignment\124_2022_4.tif
# Processed image 316: prospace_assignment\124_2022_5.tif
# Processed image 317: prospace_assignment\124_2022_6.tif
# Processed image 318: prospace_assignment\124_2022_7.tif
# Processed image 319: prospace_assignment\124_2022_8.tif
# Processed image 320: prospace_assignment\124_2022_9.tif
# Processed image 321: prospace_assignment\124_2023_0.tif
# Processed image 322: prospace_assignment\124_2023_1.tif
# Processed image 323: prospace_assignment\124_2023_2.tif
# Processed image 324: prospace_assignment\124_2023_3.tif
# Processed image 325: prospace_assignment\125_2022_10.tif
# Processed image 326: prospace_assignment\125_2022_11.tif
# Processed image 327: prospace_assignment\125_2022_4.tif
# Processed image 328: prospace_assignment\125_2022_5.tif
# Processed image 329: prospace_assignment\125_2022_6.tif
# Processed image 330: prospace_assignment\125_2022_7.tif
# Processed image 331: prospace_assignment\125_2022_8.tif
# Processed image 332: prospace_assignment\125_2022_9.tif
# Processed image 333: prospace_assignment\125_2023_0.tif
# Processed image 334: prospace_assignment\125_2023_1.tif
# Processed image 335: prospace_assignment\125_2023_2.tif
# Processed image 336: prospace_assignment\125_2023_3.tif
# Processed image 337: prospace_assignment\126_2022_10.tif
# Processed image 338: prospace_assignment\126_2022_11.tif
# Processed image 339: prospace_assignment\126_2022_4.tif
# Processed image 340: prospace_assignment\126_2022_5.tif
# Processed image 341: prospace_assignment\126_2022_6.tif
# Processed image 342: prospace_assignment\126_2022_7.tif
# Processed image 343: prospace_assignment\126_2022_8.tif
# Processed image 344: prospace_assignment\126_2022_9.tif
# Processed image 345: prospace_assignment\126_2023_0.tif
# Processed image 346: prospace_assignment\126_2023_1.tif
# Processed image 347: prospace_assignment\126_2023_2.tif
# Processed image 348: prospace_assignment\126_2023_3.tif
# Processed image 349: prospace_assignment\127_2022_10.tif
# Processed image 350: prospace_assignment\127_2022_11.tif
# Processed image 351: prospace_assignment\127_2022_4.tif
# Processed image 352: prospace_assignment\127_2022_5.tif
# Processed image 353: prospace_assignment\127_2022_6.tif
# Processed image 354: prospace_assignment\127_2022_7.tif
# Processed image 355: prospace_assignment\127_2022_8.tif
# Processed image 356: prospace_assignment\127_2022_9.tif
# Processed image 357: prospace_assignment\127_2023_0.tif
# Processed image 358: prospace_assignment\127_2023_1.tif
# Processed image 359: prospace_assignment\127_2023_2.tif
# Processed image 360: prospace_assignment\127_2023_3.tif
# Processed image 361: prospace_assignment\128_2022_10.tif
# Processed image 362: prospace_assignment\128_2022_11.tif
# Processed image 363: prospace_assignment\128_2022_4.tif
# Processed image 364: prospace_assignment\128_2022_5.tif
# Processed image 365: prospace_assignment\128_2022_6.tif
# Processed image 366: prospace_assignment\128_2022_7.tif
# Processed image 367: prospace_assignment\128_2022_8.tif
# Processed image 368: prospace_assignment\128_2022_9.tif
# Processed image 369: prospace_assignment\128_2023_0.tif
# Processed image 370: prospace_assignment\128_2023_1.tif
# Processed image 371: prospace_assignment\128_2023_2.tif
# Processed image 372: prospace_assignment\128_2023_3.tif
# Processed image 373: prospace_assignment\129_2022_10.tif
# Processed image 374: prospace_assignment\129_2022_11.tif
# Processed image 375: prospace_assignment\129_2022_4.tif
# Processed image 376: prospace_assignment\129_2022_5.tif
# Processed image 377: prospace_assignment\129_2022_6.tif
# Processed image 378: prospace_assignment\129_2022_7.tif
# Processed image 379: prospace_assignment\129_2022_8.tif
# Processed image 380: prospace_assignment\129_2022_9.tif
# Processed image 381: prospace_assignment\129_2023_0.tif
# Processed image 382: prospace_assignment\129_2023_1.tif
# Processed image 383: prospace_assignment\129_2023_2.tif
# Processed image 384: prospace_assignment\129_2023_3.tif
# Processed image 385: prospace_assignment\12_2022_10.tif
# Processed image 386: prospace_assignment\12_2022_11.tif
# Processed image 387: prospace_assignment\12_2022_4.tif
# Processed image 388: prospace_assignment\12_2022_5.tif
# Processed image 389: prospace_assignment\12_2022_6.tif
# Processed image 390: prospace_assignment\12_2022_7.tif
# Processed image 391: prospace_assignment\12_2022_8.tif
# Processed image 392: prospace_assignment\12_2022_9.tif
# Processed image 393: prospace_assignment\12_2023_0.tif
# Processed image 394: prospace_assignment\12_2023_1.tif
# Processed image 395: prospace_assignment\12_2023_2.tif
# Processed image 396: prospace_assignment\12_2023_3.tif
# Processed image 397: prospace_assignment\130_2022_10.tif
# Processed image 398: prospace_assignment\130_2022_11.tif
# Processed image 399: prospace_assignment\130_2022_4.tif
# Processed image 400: prospace_assignment\130_2022_5.tif
# Processed image 401: prospace_assignment\130_2022_6.tif
# Processed image 402: prospace_assignment\130_2022_7.tif
# Processed image 403: prospace_assignment\130_2022_8.tif
# Processed image 404: prospace_assignment\130_2022_9.tif
# Processed image 405: prospace_assignment\130_2023_0.tif
# Processed image 406: prospace_assignment\130_2023_1.tif
# Processed image 407: prospace_assignment\130_2023_2.tif
# Processed image 408: prospace_assignment\130_2023_3.tif
# Processed image 409: prospace_assignment\131_2022_10.tif
# Processed image 410: prospace_assignment\131_2022_11.tif
# Processed image 411: prospace_assignment\131_2022_4.tif
# Processed image 412: prospace_assignment\131_2022_5.tif
# Processed image 413: prospace_assignment\131_2022_6.tif
# Processed image 414: prospace_assignment\131_2022_7.tif
# Processed image 415: prospace_assignment\131_2022_8.tif
# Processed image 416: prospace_assignment\131_2022_9.tif
# Processed image 417: prospace_assignment\131_2023_0.tif
# Processed image 418: prospace_assignment\131_2023_1.tif
# Processed image 419: prospace_assignment\131_2023_2.tif
# Processed image 420: prospace_assignment\131_2023_3.tif
# Processed image 421: prospace_assignment\132_2022_10.tif
# Processed image 422: prospace_assignment\132_2022_11.tif
# Processed image 423: prospace_assignment\132_2022_4.tif
# Processed image 424: prospace_assignment\132_2022_5.tif
# Processed image 425: prospace_assignment\132_2022_6.tif
# Processed image 426: prospace_assignment\132_2022_7.tif
# Processed image 427: prospace_assignment\132_2022_8.tif
# Processed image 428: prospace_assignment\132_2022_9.tif
# Processed image 429: prospace_assignment\132_2023_0.tif
# Processed image 430: prospace_assignment\132_2023_1.tif
# Processed image 431: prospace_assignment\132_2023_2.tif
# Processed image 432: prospace_assignment\132_2023_3.tif
# Processed image 433: prospace_assignment\133_2022_10.tif
# Processed image 434: prospace_assignment\133_2022_11.tif
# Processed image 435: prospace_assignment\133_2022_4.tif
# Processed image 436: prospace_assignment\133_2022_5.tif
# Processed image 437: prospace_assignment\133_2022_6.tif
# Processed image 438: prospace_assignment\133_2022_7.tif
# Processed image 439: prospace_assignment\133_2022_8.tif
# Processed image 440: prospace_assignment\133_2022_9.tif
# Processed image 441: prospace_assignment\133_2023_0.tif
# Processed image 442: prospace_assignment\133_2023_1.tif
# Processed image 443: prospace_assignment\133_2023_2.tif
# Processed image 444: prospace_assignment\133_2023_3.tif
# Processed image 445: prospace_assignment\134_2022_10.tif
# Processed image 446: prospace_assignment\134_2022_11.tif
# Processed image 447: prospace_assignment\134_2022_4.tif
# Processed image 448: prospace_assignment\134_2022_5.tif
# Processed image 449: prospace_assignment\134_2022_6.tif
# Processed image 450: prospace_assignment\134_2022_7.tif
# Processed image 451: prospace_assignment\134_2022_8.tif
# Processed image 452: prospace_assignment\134_2022_9.tif
# Processed image 453: prospace_assignment\134_2023_0.tif
# Processed image 454: prospace_assignment\134_2023_1.tif
# Processed image 455: prospace_assignment\134_2023_2.tif
# Processed image 456: prospace_assignment\134_2023_3.tif
# Processed image 457: prospace_assignment\135_2022_10.tif
# Processed image 458: prospace_assignment\135_2022_11.tif
# Processed image 459: prospace_assignment\135_2022_4.tif
# Processed image 460: prospace_assignment\135_2022_5.tif
# Processed image 461: prospace_assignment\135_2022_6.tif
# Processed image 462: prospace_assignment\135_2022_7.tif
# Processed image 463: prospace_assignment\135_2022_8.tif
# Processed image 464: prospace_assignment\135_2022_9.tif
# Processed image 465: prospace_assignment\135_2023_0.tif
# Processed image 466: prospace_assignment\135_2023_1.tif
# Processed image 467: prospace_assignment\135_2023_2.tif
# Processed image 468: prospace_assignment\135_2023_3.tif
# Processed image 469: prospace_assignment\136_2022_10.tif
# Processed image 470: prospace_assignment\136_2022_11.tif
# Processed image 471: prospace_assignment\136_2022_4.tif
# Processed image 472: prospace_assignment\136_2022_5.tif
# Processed image 473: prospace_assignment\136_2022_6.tif
# Processed image 474: prospace_assignment\136_2022_7.tif
# Processed image 475: prospace_assignment\136_2022_8.tif
# Processed image 476: prospace_assignment\136_2022_9.tif
# Processed image 477: prospace_assignment\136_2023_0.tif
# Processed image 478: prospace_assignment\136_2023_1.tif
# Processed image 479: prospace_assignment\136_2023_2.tif
# Processed image 480: prospace_assignment\136_2023_3.tif
# Processed image 481: prospace_assignment\137_2022_10.tif
# Processed image 482: prospace_assignment\137_2022_11.tif
# Processed image 483: prospace_assignment\137_2022_4.tif
# Processed image 484: prospace_assignment\137_2022_5.tif
# Processed image 485: prospace_assignment\137_2022_6.tif
# Processed image 486: prospace_assignment\137_2022_7.tif
# Processed image 487: prospace_assignment\137_2022_8.tif
# Processed image 488: prospace_assignment\137_2022_9.tif
# Processed image 489: prospace_assignment\137_2023_0.tif
# Processed image 490: prospace_assignment\137_2023_1.tif
# Processed image 491: prospace_assignment\137_2023_2.tif
# Processed image 492: prospace_assignment\137_2023_3.tif
# Processed image 493: prospace_assignment\138_2022_10.tif
# Processed image 494: prospace_assignment\138_2022_11.tif
# Processed image 495: prospace_assignment\138_2022_4.tif
# Processed image 496: prospace_assignment\138_2022_5.tif
# Processed image 497: prospace_assignment\138_2022_6.tif
# Processed image 498: prospace_assignment\138_2022_7.tif
# Processed image 499: prospace_assignment\138_2022_8.tif
# Processed image 500: prospace_assignment\138_2022_9.tif
# Processed image 501: prospace_assignment\138_2023_0.tif
# Processed image 502: prospace_assignment\138_2023_1.tif
# Processed image 503: prospace_assignment\138_2023_2.tif
# Processed image 504: prospace_assignment\138_2023_3.tif
# Processed image 505: prospace_assignment\139_2022_10.tif
# Processed image 506: prospace_assignment\139_2022_11.tif
# Processed image 507: prospace_assignment\139_2022_4.tif
# Processed image 508: prospace_assignment\139_2022_5.tif
# Processed image 509: prospace_assignment\139_2022_6.tif
# Processed image 510: prospace_assignment\139_2022_7.tif
# Processed image 511: prospace_assignment\139_2022_8.tif
# Processed image 512: prospace_assignment\139_2022_9.tif
# Processed image 513: prospace_assignment\139_2023_0.tif
# Processed image 514: prospace_assignment\139_2023_1.tif
# Processed image 515: prospace_assignment\139_2023_2.tif
# Processed image 516: prospace_assignment\139_2023_3.tif
# Processed image 517: prospace_assignment\13_2022_10.tif
# Processed image 518: prospace_assignment\13_2022_11.tif
# Processed image 519: prospace_assignment\13_2022_4.tif
# Processed image 520: prospace_assignment\13_2022_5.tif
# Processed image 521: prospace_assignment\13_2022_6.tif
# Processed image 522: prospace_assignment\13_2022_7.tif
# Processed image 523: prospace_assignment\13_2022_8.tif
# Processed image 524: prospace_assignment\13_2022_9.tif
# Processed image 525: prospace_assignment\13_2023_0.tif
# Processed image 526: prospace_assignment\13_2023_1.tif
# Processed image 527: prospace_assignment\13_2023_2.tif
# Processed image 528: prospace_assignment\13_2023_3.tif
# Processed image 529: prospace_assignment\140_2022_10.tif
# Processed image 530: prospace_assignment\140_2022_11.tif
# Processed image 531: prospace_assignment\140_2022_4.tif
# Processed image 532: prospace_assignment\140_2022_5.tif
# Processed image 533: prospace_assignment\140_2022_6.tif
# Processed image 534: prospace_assignment\140_2022_7.tif
# Processed image 535: prospace_assignment\140_2022_8.tif
# Processed image 536: prospace_assignment\140_2022_9.tif
# Processed image 537: prospace_assignment\140_2023_0.tif
# Processed image 538: prospace_assignment\140_2023_1.tif
# Processed image 539: prospace_assignment\140_2023_2.tif
# Processed image 540: prospace_assignment\140_2023_3.tif
# Processed image 541: prospace_assignment\141_2022_10.tif
# Processed image 542: prospace_assignment\141_2022_11.tif
# Processed image 543: prospace_assignment\141_2022_4.tif
# Processed image 544: prospace_assignment\141_2022_5.tif
# Processed image 545: prospace_assignment\141_2022_6.tif
# Processed image 546: prospace_assignment\141_2022_7.tif
# Processed image 547: prospace_assignment\141_2022_8.tif
# Processed image 548: prospace_assignment\141_2022_9.tif
# Processed image 549: prospace_assignment\141_2023_0.tif
# Processed image 550: prospace_assignment\141_2023_1.tif
# Processed image 551: prospace_assignment\141_2023_2.tif
# Processed image 552: prospace_assignment\141_2023_3.tif
# Processed image 553: prospace_assignment\142_2022_10.tif
# Processed image 554: prospace_assignment\142_2022_11.tif
# Processed image 555: prospace_assignment\142_2022_4.tif
# Processed image 556: prospace_assignment\142_2022_5.tif
# Processed image 557: prospace_assignment\142_2022_6.tif
# Processed image 558: prospace_assignment\142_2022_7.tif
# Processed image 559: prospace_assignment\142_2022_8.tif
# Processed image 560: prospace_assignment\142_2022_9.tif
# Processed image 561: prospace_assignment\142_2023_0.tif
# Processed image 562: prospace_assignment\142_2023_1.tif
# Processed image 563: prospace_assignment\142_2023_2.tif
# Processed image 564: prospace_assignment\142_2023_3.tif
# Processed image 565: prospace_assignment\143_2022_10.tif
# Processed image 566: prospace_assignment\143_2022_11.tif
# Processed image 567: prospace_assignment\143_2022_4.tif
# Processed image 568: prospace_assignment\143_2022_5.tif
# Processed image 569: prospace_assignment\143_2022_6.tif
# Processed image 570: prospace_assignment\143_2022_7.tif
# Processed image 571: prospace_assignment\143_2022_8.tif
# Processed image 572: prospace_assignment\143_2022_9.tif
# Processed image 573: prospace_assignment\143_2023_0.tif
# Processed image 574: prospace_assignment\143_2023_1.tif
# Processed image 575: prospace_assignment\143_2023_2.tif
# Processed image 576: prospace_assignment\143_2023_3.tif
# Processed image 577: prospace_assignment\144_2022_10.tif
# Processed image 578: prospace_assignment\144_2022_11.tif
# Processed image 579: prospace_assignment\144_2022_4.tif
# Processed image 580: prospace_assignment\144_2022_5.tif
# Processed image 581: prospace_assignment\144_2022_6.tif
# Processed image 582: prospace_assignment\144_2022_7.tif
# Processed image 583: prospace_assignment\144_2022_8.tif
# Processed image 584: prospace_assignment\144_2022_9.tif
# Processed image 585: prospace_assignment\144_2023_0.tif
# Processed image 586: prospace_assignment\144_2023_1.tif
# Processed image 587: prospace_assignment\144_2023_2.tif
# Processed image 588: prospace_assignment\144_2023_3.tif
# Processed image 589: prospace_assignment\145_2022_10.tif
# Processed image 590: prospace_assignment\145_2022_11.tif
# Processed image 591: prospace_assignment\145_2022_4.tif
# Processed image 592: prospace_assignment\145_2022_5.tif
# Processed image 593: prospace_assignment\145_2022_6.tif
# Processed image 594: prospace_assignment\145_2022_7.tif
# Processed image 595: prospace_assignment\145_2022_8.tif
# Processed image 596: prospace_assignment\145_2022_9.tif
# Processed image 597: prospace_assignment\145_2023_0.tif
# Processed image 598: prospace_assignment\145_2023_1.tif
# Processed image 599: prospace_assignment\145_2023_2.tif
# Processed image 600: prospace_assignment\145_2023_3.tif
# Processed image 601: prospace_assignment\146_2022_10.tif
# Processed image 602: prospace_assignment\146_2022_11.tif
# Processed image 603: prospace_assignment\146_2022_4.tif
# Processed image 604: prospace_assignment\146_2022_5.tif
# Processed image 605: prospace_assignment\146_2022_6.tif
# Processed image 606: prospace_assignment\146_2022_7.tif
# Processed image 607: prospace_assignment\146_2022_8.tif
# Processed image 608: prospace_assignment\146_2022_9.tif
# Processed image 609: prospace_assignment\146_2023_0.tif
# Processed image 610: prospace_assignment\146_2023_1.tif
# Processed image 611: prospace_assignment\146_2023_2.tif
# Processed image 612: prospace_assignment\146_2023_3.tif
# Processed image 613: prospace_assignment\147_2022_10.tif
# Processed image 614: prospace_assignment\147_2022_11.tif
# Processed image 615: prospace_assignment\147_2022_4.tif
# Processed image 616: prospace_assignment\147_2022_5.tif
# Processed image 617: prospace_assignment\147_2022_6.tif
# Processed image 618: prospace_assignment\147_2022_7.tif
# Processed image 619: prospace_assignment\147_2022_8.tif
# Processed image 620: prospace_assignment\147_2022_9.tif
# Processed image 621: prospace_assignment\147_2023_0.tif
# Processed image 622: prospace_assignment\147_2023_1.tif
# Processed image 623: prospace_assignment\147_2023_2.tif
# Processed image 624: prospace_assignment\147_2023_3.tif
# Processed image 625: prospace_assignment\148_2022_10.tif
# Processed image 626: prospace_assignment\148_2022_11.tif
# Processed image 627: prospace_assignment\148_2022_4.tif
# Processed image 628: prospace_assignment\148_2022_5.tif
# Processed image 629: prospace_assignment\148_2022_6.tif
# Processed image 630: prospace_assignment\148_2022_7.tif
# Processed image 631: prospace_assignment\148_2022_8.tif
# Processed image 632: prospace_assignment\148_2022_9.tif
# Processed image 633: prospace_assignment\148_2023_0.tif
# Processed image 634: prospace_assignment\148_2023_1.tif
# Processed image 635: prospace_assignment\148_2023_2.tif
# Processed image 636: prospace_assignment\148_2023_3.tif
# Processed image 637: prospace_assignment\149_2022_10.tif
# Processed image 638: prospace_assignment\149_2022_11.tif
# Processed image 639: prospace_assignment\149_2022_4.tif
# Processed image 640: prospace_assignment\149_2022_5.tif
# Processed image 641: prospace_assignment\149_2022_6.tif
# Processed image 642: prospace_assignment\149_2022_7.tif
# Processed image 643: prospace_assignment\149_2022_8.tif
# Processed image 644: prospace_assignment\149_2022_9.tif
# Processed image 645: prospace_assignment\149_2023_0.tif
# Processed image 646: prospace_assignment\149_2023_1.tif
# Processed image 647: prospace_assignment\149_2023_2.tif
# Processed image 648: prospace_assignment\149_2023_3.tif
# Processed image 649: prospace_assignment\14_2022_10.tif
# Processed image 650: prospace_assignment\14_2022_11.tif
# Processed image 651: prospace_assignment\14_2022_4.tif
# Processed image 652: prospace_assignment\14_2022_5.tif
# Processed image 653: prospace_assignment\14_2022_6.tif
# Processed image 654: prospace_assignment\14_2022_7.tif
# Processed image 655: prospace_assignment\14_2022_8.tif
# Processed image 656: prospace_assignment\14_2022_9.tif
# Processed image 657: prospace_assignment\14_2023_0.tif
# Processed image 658: prospace_assignment\14_2023_1.tif
# Processed image 659: prospace_assignment\14_2023_2.tif
# Processed image 660: prospace_assignment\14_2023_3.tif
# Processed image 661: prospace_assignment\150_2022_10.tif
# Processed image 662: prospace_assignment\150_2022_11.tif
# Processed image 663: prospace_assignment\150_2022_4.tif
# Processed image 664: prospace_assignment\150_2022_5.tif
# Processed image 665: prospace_assignment\150_2022_6.tif
# Processed image 666: prospace_assignment\150_2022_7.tif
# Processed image 667: prospace_assignment\150_2022_8.tif
# Processed image 668: prospace_assignment\150_2022_9.tif
# Processed image 669: prospace_assignment\150_2023_0.tif
# Processed image 670: prospace_assignment\150_2023_1.tif
# Processed image 671: prospace_assignment\150_2023_2.tif
# Processed image 672: prospace_assignment\150_2023_3.tif
# Processed image 673: prospace_assignment\151_2022_10.tif
# Processed image 674: prospace_assignment\151_2022_11.tif
# Processed image 675: prospace_assignment\151_2022_4.tif
# Processed image 676: prospace_assignment\151_2022_5.tif
# Processed image 677: prospace_assignment\151_2022_6.tif
# Processed image 678: prospace_assignment\151_2022_7.tif
# Processed image 679: prospace_assignment\151_2022_8.tif
# Processed image 680: prospace_assignment\151_2022_9.tif
# Processed image 681: prospace_assignment\151_2023_0.tif
# Processed image 682: prospace_assignment\151_2023_1.tif
# Processed image 683: prospace_assignment\151_2023_2.tif
# Processed image 684: prospace_assignment\151_2023_3.tif
# Processed image 685: prospace_assignment\152_2022_10.tif
# Processed image 686: prospace_assignment\152_2022_11.tif
# Processed image 687: prospace_assignment\152_2022_4.tif
# Processed image 688: prospace_assignment\152_2022_5.tif
# Processed image 689: prospace_assignment\152_2022_6.tif
# Processed image 690: prospace_assignment\152_2022_7.tif
# Processed image 691: prospace_assignment\152_2022_8.tif
# Processed image 692: prospace_assignment\152_2022_9.tif
# Processed image 693: prospace_assignment\152_2023_0.tif
# Processed image 694: prospace_assignment\152_2023_1.tif
# Processed image 695: prospace_assignment\152_2023_2.tif
# Processed image 696: prospace_assignment\152_2023_3.tif
# Processed image 697: prospace_assignment\153_2022_10.tif
# Processed image 698: prospace_assignment\153_2022_11.tif
# Processed image 699: prospace_assignment\153_2022_4.tif
# Processed image 700: prospace_assignment\153_2022_5.tif
# Processed image 701: prospace_assignment\153_2022_6.tif
# Processed image 702: prospace_assignment\153_2022_7.tif
# Processed image 703: prospace_assignment\153_2022_8.tif
# Processed image 704: prospace_assignment\153_2022_9.tif
# Processed image 705: prospace_assignment\153_2023_0.tif
# Processed image 706: prospace_assignment\153_2023_1.tif
# Processed image 707: prospace_assignment\153_2023_2.tif
# Processed image 708: prospace_assignment\153_2023_3.tif
# Processed image 709: prospace_assignment\154_2022_10.tif
# Processed image 710: prospace_assignment\154_2022_11.tif
# Processed image 711: prospace_assignment\154_2022_4.tif
# Processed image 712: prospace_assignment\154_2022_5.tif
# Processed image 713: prospace_assignment\154_2022_6.tif
# Processed image 714: prospace_assignment\154_2022_7.tif
# Processed image 715: prospace_assignment\154_2022_8.tif
# Processed image 716: prospace_assignment\154_2022_9.tif
# Processed image 717: prospace_assignment\154_2023_0.tif
# Processed image 718: prospace_assignment\154_2023_1.tif
# Processed image 719: prospace_assignment\154_2023_2.tif
# Processed image 720: prospace_assignment\154_2023_3.tif
# Processed image 721: prospace_assignment\155_2022_10.tif
# Processed image 722: prospace_assignment\155_2022_11.tif
# Processed image 723: prospace_assignment\155_2022_4.tif
# Processed image 724: prospace_assignment\155_2022_5.tif
# Processed image 725: prospace_assignment\155_2022_6.tif
# Processed image 726: prospace_assignment\155_2022_7.tif
# Processed image 727: prospace_assignment\155_2022_8.tif
# Processed image 728: prospace_assignment\155_2022_9.tif
# Processed image 729: prospace_assignment\155_2023_0.tif
# Processed image 730: prospace_assignment\155_2023_1.tif
# Processed image 731: prospace_assignment\155_2023_2.tif
# Processed image 732: prospace_assignment\155_2023_3.tif
# Processed image 733: prospace_assignment\156_2022_10.tif
# Processed image 734: prospace_assignment\156_2022_11.tif
# Processed image 735: prospace_assignment\156_2022_4.tif
# Processed image 736: prospace_assignment\156_2022_5.tif
# Processed image 737: prospace_assignment\156_2022_6.tif
# Processed image 738: prospace_assignment\156_2022_7.tif
# Processed image 739: prospace_assignment\156_2022_8.tif
# Processed image 740: prospace_assignment\156_2022_9.tif
# Processed image 741: prospace_assignment\156_2023_0.tif
# Processed image 742: prospace_assignment\156_2023_1.tif
# Processed image 743: prospace_assignment\156_2023_2.tif
# Processed image 744: prospace_assignment\156_2023_3.tif
# Processed image 745: prospace_assignment\157_2022_10.tif
# Processed image 746: prospace_assignment\157_2022_11.tif
# Processed image 747: prospace_assignment\157_2022_4.tif
# Processed image 748: prospace_assignment\157_2022_5.tif
# Processed image 749: prospace_assignment\157_2022_6.tif
# Processed image 750: prospace_assignment\157_2022_7.tif
# Processed image 751: prospace_assignment\157_2022_8.tif
# Processed image 752: prospace_assignment\157_2022_9.tif
# Processed image 753: prospace_assignment\157_2023_0.tif
# Processed image 754: prospace_assignment\157_2023_1.tif
# Processed image 755: prospace_assignment\157_2023_2.tif
# Processed image 756: prospace_assignment\157_2023_3.tif
# Processed image 757: prospace_assignment\158_2022_10.tif
# Processed image 758: prospace_assignment\158_2022_11.tif
# Processed image 759: prospace_assignment\158_2022_4.tif
# Processed image 760: prospace_assignment\158_2022_5.tif
# Processed image 761: prospace_assignment\158_2022_6.tif
# Processed image 762: prospace_assignment\158_2022_7.tif
# Processed image 763: prospace_assignment\158_2022_8.tif
# Processed image 764: prospace_assignment\158_2022_9.tif
# Processed image 765: prospace_assignment\158_2023_0.tif
# Processed image 766: prospace_assignment\158_2023_1.tif
# Processed image 767: prospace_assignment\158_2023_2.tif
# Processed image 768: prospace_assignment\158_2023_3.tif
# Processed image 769: prospace_assignment\159_2022_10.tif
# Processed image 770: prospace_assignment\159_2022_11.tif
# Processed image 771: prospace_assignment\159_2022_4.tif
# Processed image 772: prospace_assignment\159_2022_5.tif
# Processed image 773: prospace_assignment\159_2022_6.tif
# Processed image 774: prospace_assignment\159_2022_7.tif
# Processed image 775: prospace_assignment\159_2022_8.tif
# Processed image 776: prospace_assignment\159_2022_9.tif
# Processed image 777: prospace_assignment\159_2023_0.tif
# Processed image 778: prospace_assignment\159_2023_1.tif
# Processed image 779: prospace_assignment\159_2023_2.tif
# Processed image 780: prospace_assignment\159_2023_3.tif
# Processed image 781: prospace_assignment\15_2022_10.tif
# Processed image 782: prospace_assignment\15_2022_11.tif
# Processed image 783: prospace_assignment\15_2022_4.tif
# Processed image 784: prospace_assignment\15_2022_5.tif
# Processed image 785: prospace_assignment\15_2022_6.tif
# Processed image 786: prospace_assignment\15_2022_7.tif
# Processed image 787: prospace_assignment\15_2022_8.tif
# Processed image 788: prospace_assignment\15_2022_9.tif
# Processed image 789: prospace_assignment\15_2023_0.tif
# Processed image 790: prospace_assignment\15_2023_1.tif
# Processed image 791: prospace_assignment\15_2023_2.tif
# Processed image 792: prospace_assignment\15_2023_3.tif
# Processed image 793: prospace_assignment\160_2022_10.tif
# Processed image 794: prospace_assignment\160_2022_11.tif
# Processed image 795: prospace_assignment\160_2022_4.tif
# Processed image 796: prospace_assignment\160_2022_5.tif
# Processed image 797: prospace_assignment\160_2022_6.tif
# Processed image 798: prospace_assignment\160_2022_7.tif
# Processed image 799: prospace_assignment\160_2022_8.tif
# Processed image 800: prospace_assignment\160_2022_9.tif
# Processed image 801: prospace_assignment\160_2023_0.tif
# Processed image 802: prospace_assignment\160_2023_1.tif
# Processed image 803: prospace_assignment\160_2023_2.tif
# Processed image 804: prospace_assignment\160_2023_3.tif
# Processed image 805: prospace_assignment\161_2022_10.tif
# Processed image 806: prospace_assignment\161_2022_11.tif
# Processed image 807: prospace_assignment\161_2022_4.tif
# Processed image 808: prospace_assignment\161_2022_5.tif
# Processed image 809: prospace_assignment\161_2022_6.tif
# Processed image 810: prospace_assignment\161_2022_7.tif
# Processed image 811: prospace_assignment\161_2022_8.tif
# Processed image 812: prospace_assignment\161_2022_9.tif
# Processed image 813: prospace_assignment\161_2023_0.tif
# Processed image 814: prospace_assignment\161_2023_1.tif
# Processed image 815: prospace_assignment\161_2023_2.tif
# Processed image 816: prospace_assignment\161_2023_3.tif
# Processed image 817: prospace_assignment\162_2022_10.tif
# Processed image 818: prospace_assignment\162_2022_11.tif
# Processed image 819: prospace_assignment\162_2022_4.tif
# Processed image 820: prospace_assignment\162_2022_5.tif
# Processed image 821: prospace_assignment\162_2022_6.tif
# Processed image 822: prospace_assignment\162_2022_7.tif
# Processed image 823: prospace_assignment\162_2022_8.tif
# Processed image 824: prospace_assignment\162_2022_9.tif
# Processed image 825: prospace_assignment\162_2023_0.tif
# Processed image 826: prospace_assignment\162_2023_1.tif
# Processed image 827: prospace_assignment\162_2023_2.tif
# Processed image 828: prospace_assignment\162_2023_3.tif
# Processed image 829: prospace_assignment\163_2022_10.tif
# Processed image 830: prospace_assignment\163_2022_11.tif
# Processed image 831: prospace_assignment\163_2022_4.tif
# Processed image 832: prospace_assignment\163_2022_5.tif
# Processed image 833: prospace_assignment\163_2022_6.tif
# Processed image 834: prospace_assignment\163_2022_7.tif
# Processed image 835: prospace_assignment\163_2022_8.tif
# Processed image 836: prospace_assignment\163_2022_9.tif
# Processed image 837: prospace_assignment\163_2023_0.tif
# Processed image 838: prospace_assignment\163_2023_1.tif
# Processed image 839: prospace_assignment\163_2023_2.tif
# Processed image 840: prospace_assignment\163_2023_3.tif
# Processed image 841: prospace_assignment\164_2022_10.tif
# Processed image 842: prospace_assignment\164_2022_11.tif
# Processed image 843: prospace_assignment\164_2022_4.tif
# Processed image 844: prospace_assignment\164_2022_5.tif
# Processed image 845: prospace_assignment\164_2022_6.tif
# Processed image 846: prospace_assignment\164_2022_7.tif
# Processed image 847: prospace_assignment\164_2022_8.tif
# Processed image 848: prospace_assignment\164_2022_9.tif
# Processed image 849: prospace_assignment\164_2023_0.tif
# Processed image 850: prospace_assignment\164_2023_1.tif
# Processed image 851: prospace_assignment\164_2023_2.tif
# Processed image 852: prospace_assignment\164_2023_3.tif
# Processed image 853: prospace_assignment\165_2022_10.tif
# Processed image 854: prospace_assignment\165_2022_11.tif
# Processed image 855: prospace_assignment\165_2022_4.tif
# Processed image 856: prospace_assignment\165_2022_5.tif
# Processed image 857: prospace_assignment\165_2022_6.tif
# ...
# Processed image 6532: prospace_assignment\79_2022_5.tif
# Processed image 6533: prospace_assignment\79_2022_6.tif
# Processed image 6534: prospace_assignment\79_2022_7.tif
# Processed image 6535: prospace_assignment\79_2022_8.tif
# Processed image 6536: prospace_assignment\79_2022_9.tif
# Processed image 6537: prospace_assignment\79_2023_0.tif
# Processed image 6538: prospace_assignment\79_2023_1.tif
# Processed image 6539: prospace_assignment\79_2023_2.tif
# Processed image 6540: prospace_assignment\79_2023_3.tif
# Processed image 6541: prospace_assignment\7_2022_10.tif
# Processed image 6542: prospace_assignment\7_2022_11.tif
# Processed image 6543: prospace_assignment\7_2022_4.tif
# Processed image 6544: prospace_assignment\7_2022_5.tif
# Processed image 6545: prospace_assignment\7_2022_6.tif
# Processed image 6546: prospace_assignment\7_2022_7.tif
# Processed image 6547: prospace_assignment\7_2022_8.tif
# Processed image 6548: prospace_assignment\7_2022_9.tif
# Processed image 6549: prospace_assignment\7_2023_0.tif
# Processed image 6550: prospace_assignment\7_2023_1.tif
# Processed image 6551: prospace_assignment\7_2023_2.tif
# Processed image 6552: prospace_assignment\7_2023_3.tif
# Processed image 6553: prospace_assignment\80_2022_10.tif
# Processed image 6554: prospace_assignment\80_2022_11.tif
# Processed image 6555: prospace_assignment\80_2022_4.tif
# Processed image 6556: prospace_assignment\80_2022_5.tif
# Processed image 6557: prospace_assignment\80_2022_6.tif
# Processed image 6558: prospace_assignment\80_2022_7.tif
# Processed image 6559: prospace_assignment\80_2022_8.tif
# Processed image 6560: prospace_assignment\80_2022_9.tif
# Processed image 6561: prospace_assignment\80_2023_0.tif
# Processed image 6562: prospace_assignment\80_2023_1.tif
# Processed image 6563: prospace_assignment\80_2023_2.tif
# Processed image 6564: prospace_assignment\80_2023_3.tif
# Processed image 6565: prospace_assignment\81_2022_10.tif
# Processed image 6566: prospace_assignment\81_2022_11.tif
# Processed image 6567: prospace_assignment\81_2022_4.tif
# Processed image 6568: prospace_assignment\81_2022_5.tif
# Processed image 6569: prospace_assignment\81_2022_6.tif
# Processed image 6570: prospace_assignment\81_2022_7.tif
# Processed image 6571: prospace_assignment\81_2022_8.tif
# Processed image 6572: prospace_assignment\81_2022_9.tif
# Processed image 6573: prospace_assignment\81_2023_0.tif
# Processed image 6574: prospace_assignment\81_2023_1.tif
# Processed image 6575: prospace_assignment\81_2023_2.tif
# Processed image 6576: prospace_assignment\81_2023_3.tif
# Processed image 6577: prospace_assignment\82_2022_10.tif
# Processed image 6578: prospace_assignment\82_2022_11.tif
# Processed image 6579: prospace_assignment\82_2022_4.tif
# Processed image 6580: prospace_assignment\82_2022_5.tif
# Processed image 6581: prospace_assignment\82_2022_6.tif
# Processed image 6582: prospace_assignment\82_2022_7.tif
# Processed image 6583: prospace_assignment\82_2022_8.tif
# Processed image 6584: prospace_assignment\82_2022_9.tif
# Processed image 6585: prospace_assignment\82_2023_0.tif
# Processed image 6586: prospace_assignment\82_2023_1.tif
# Processed image 6587: prospace_assignment\82_2023_2.tif
# Processed image 6588: prospace_assignment\82_2023_3.tif
# Processed image 6589: prospace_assignment\83_2022_10.tif
# Processed image 6590: prospace_assignment\83_2022_11.tif
# Processed image 6591: prospace_assignment\83_2022_4.tif
# Processed image 6592: prospace_assignment\83_2022_5.tif
# Processed image 6593: prospace_assignment\83_2022_6.tif
# Processed image 6594: prospace_assignment\83_2022_7.tif
# Processed image 6595: prospace_assignment\83_2022_8.tif
# Processed image 6596: prospace_assignment\83_2022_9.tif
# Processed image 6597: prospace_assignment\83_2023_0.tif
# Processed image 6598: prospace_assignment\83_2023_1.tif
# Processed image 6599: prospace_assignment\83_2023_2.tif
# Processed image 6600: prospace_assignment\83_2023_3.tif
# Processed image 6601: prospace_assignment\84_2022_10.tif
# Processed image 6602: prospace_assignment\84_2022_11.tif
# Processed image 6603: prospace_assignment\84_2022_4.tif
# Processed image 6604: prospace_assignment\84_2022_5.tif
# Processed image 6605: prospace_assignment\84_2022_6.tif
# Processed image 6606: prospace_assignment\84_2022_7.tif
# Processed image 6607: prospace_assignment\84_2022_8.tif
# Processed image 6608: prospace_assignment\84_2022_9.tif
# Processed image 6609: prospace_assignment\84_2023_0.tif
# Processed image 6610: prospace_assignment\84_2023_1.tif
# Processed image 6611: prospace_assignment\84_2023_2.tif
# Processed image 6612: prospace_assignment\84_2023_3.tif
# Processed image 6613: prospace_assignment\85_2022_10.tif
# Processed image 6614: prospace_assignment\85_2022_11.tif
# Processed image 6615: prospace_assignment\85_2022_4.tif
# Processed image 6616: prospace_assignment\85_2022_5.tif
# Processed image 6617: prospace_assignment\85_2022_6.tif
# Processed image 6618: prospace_assignment\85_2022_7.tif
# Processed image 6619: prospace_assignment\85_2022_8.tif
# Processed image 6620: prospace_assignment\85_2022_9.tif
# Processed image 6621: prospace_assignment\85_2023_0.tif
# Processed image 6622: prospace_assignment\85_2023_1.tif
# Processed image 6623: prospace_assignment\85_2023_2.tif
# Processed image 6624: prospace_assignment\85_2023_3.tif
# Processed image 6625: prospace_assignment\86_2022_10.tif
# Processed image 6626: prospace_assignment\86_2022_11.tif
# Processed image 6627: prospace_assignment\86_2022_4.tif
# Processed image 6628: prospace_assignment\86_2022_5.tif
# Processed image 6629: prospace_assignment\86_2022_6.tif
# Processed image 6630: prospace_assignment\86_2022_7.tif
# Processed image 6631: prospace_assignment\86_2022_8.tif
# Processed image 6632: prospace_assignment\86_2022_9.tif
# Processed image 6633: prospace_assignment\86_2023_0.tif
# Processed image 6634: prospace_assignment\86_2023_1.tif
# Processed image 6635: prospace_assignment\86_2023_2.tif
# Processed image 6636: prospace_assignment\86_2023_3.tif
# Processed image 6637: prospace_assignment\87_2022_10.tif
# Processed image 6638: prospace_assignment\87_2022_11.tif
# Processed image 6639: prospace_assignment\87_2022_4.tif
# Processed image 6640: prospace_assignment\87_2022_5.tif
# Processed image 6641: prospace_assignment\87_2022_6.tif
# Processed image 6642: prospace_assignment\87_2022_7.tif
# Processed image 6643: prospace_assignment\87_2022_8.tif
# Processed image 6644: prospace_assignment\87_2022_9.tif
# Processed image 6645: prospace_assignment\87_2023_0.tif
# Processed image 6646: prospace_assignment\87_2023_1.tif
# Processed image 6647: prospace_assignment\87_2023_2.tif
# Processed image 6648: prospace_assignment\87_2023_3.tif
# Processed image 6649: prospace_assignment\88_2022_10.tif
# Processed image 6650: prospace_assignment\88_2022_11.tif
# Processed image 6651: prospace_assignment\88_2022_4.tif
# Processed image 6652: prospace_assignment\88_2022_5.tif
# Processed image 6653: prospace_assignment\88_2022_6.tif
# Processed image 6654: prospace_assignment\88_2022_7.tif
# Processed image 6655: prospace_assignment\88_2022_8.tif
# Processed image 6656: prospace_assignment\88_2022_9.tif
# Processed image 6657: prospace_assignment\88_2023_0.tif
# Processed image 6658: prospace_assignment\88_2023_1.tif
# Processed image 6659: prospace_assignment\88_2023_2.tif
# Processed image 6660: prospace_assignment\88_2023_3.tif
# Processed image 6661: prospace_assignment\89_2022_10.tif
# Processed image 6662: prospace_assignment\89_2022_11.tif
# Processed image 6663: prospace_assignment\89_2022_4.tif
# Processed image 6664: prospace_assignment\89_2022_5.tif
# Processed image 6665: prospace_assignment\89_2022_6.tif
# Processed image 6666: prospace_assignment\89_2022_7.tif
# Processed image 6667: prospace_assignment\89_2022_8.tif
# Processed image 6668: prospace_assignment\89_2022_9.tif
# Processed image 6669: prospace_assignment\89_2023_0.tif
# Processed image 6670: prospace_assignment\89_2023_1.tif
# Processed image 6671: prospace_assignment\89_2023_2.tif
# Processed image 6672: prospace_assignment\89_2023_3.tif
# Processed image 6673: prospace_assignment\8_2022_10.tif
# Processed image 6674: prospace_assignment\8_2022_11.tif
# Processed image 6675: prospace_assignment\8_2022_4.tif
# Processed image 6676: prospace_assignment\8_2022_5.tif
# Processed image 6677: prospace_assignment\8_2022_6.tif
# Processed image 6678: prospace_assignment\8_2022_7.tif
# Processed image 6679: prospace_assignment\8_2022_8.tif
# Processed image 6680: prospace_assignment\8_2022_9.tif
# Processed image 6681: prospace_assignment\8_2023_0.tif
# Processed image 6682: prospace_assignment\8_2023_1.tif
# Processed image 6683: prospace_assignment\8_2023_2.tif
# Processed image 6684: prospace_assignment\8_2023_3.tif
# Processed image 6685: prospace_assignment\90_2022_10.tif
# Processed image 6686: prospace_assignment\90_2022_11.tif
# Processed image 6687: prospace_assignment\90_2022_4.tif
# Processed image 6688: prospace_assignment\90_2022_5.tif
# Processed image 6689: prospace_assignment\90_2022_6.tif
# Processed image 6690: prospace_assignment\90_2022_7.tif
# Processed image 6691: prospace_assignment\90_2022_8.tif
# Processed image 6692: prospace_assignment\90_2022_9.tif
# Processed image 6693: prospace_assignment\90_2023_0.tif
# Processed image 6694: prospace_assignment\90_2023_1.tif
# Processed image 6695: prospace_assignment\90_2023_2.tif
# Processed image 6696: prospace_assignment\90_2023_3.tif
# Processed image 6697: prospace_assignment\91_2022_10.tif
# Processed image 6698: prospace_assignment\91_2022_11.tif
# Processed image 6699: prospace_assignment\91_2022_4.tif
# Processed image 6700: prospace_assignment\91_2022_5.tif
# Processed image 6701: prospace_assignment\91_2022_6.tif
# Processed image 6702: prospace_assignment\91_2022_7.tif
# Processed image 6703: prospace_assignment\91_2022_8.tif
# Processed image 6704: prospace_assignment\91_2022_9.tif
# Processed image 6705: prospace_assignment\91_2023_0.tif
# Processed image 6706: prospace_assignment\91_2023_1.tif
# Processed image 6707: prospace_assignment\91_2023_2.tif
# Processed image 6708: prospace_assignment\91_2023_3.tif
# Processed image 6709: prospace_assignment\92_2022_10.tif
# Processed image 6710: prospace_assignment\92_2022_11.tif
# Processed image 6711: prospace_assignment\92_2022_4.tif
# Processed image 6712: prospace_assignment\92_2022_5.tif
# Processed image 6713: prospace_assignment\92_2022_6.tif
# Processed image 6714: prospace_assignment\92_2022_7.tif
# Processed image 6715: prospace_assignment\92_2022_8.tif
# Processed image 6716: prospace_assignment\92_2022_9.tif
# Processed image 6717: prospace_assignment\92_2023_0.tif
# Processed image 6718: prospace_assignment\92_2023_1.tif
# Processed image 6719: prospace_assignment\92_2023_2.tif
# Processed image 6720: prospace_assignment\92_2023_3.tif
# Processed image 6721: prospace_assignment\93_2022_10.tif
# Processed image 6722: prospace_assignment\93_2022_11.tif
# Processed image 6723: prospace_assignment\93_2022_4.tif
# Processed image 6724: prospace_assignment\93_2022_5.tif
# Processed image 6725: prospace_assignment\93_2022_6.tif
# Processed image 6726: prospace_assignment\93_2022_7.tif
# Processed image 6727: prospace_assignment\93_2022_8.tif
# Processed image 6728: prospace_assignment\93_2022_9.tif
# Processed image 6729: prospace_assignment\93_2023_0.tif
# Processed image 6730: prospace_assignment\93_2023_1.tif
# Processed image 6731: prospace_assignment\93_2023_2.tif
# Processed image 6732: prospace_assignment\93_2023_3.tif
# Processed image 6733: prospace_assignment\94_2022_10.tif
# Processed image 6734: prospace_assignment\94_2022_11.tif
# Processed image 6735: prospace_assignment\94_2022_4.tif
# Processed image 6736: prospace_assignment\94_2022_5.tif
# Processed image 6737: prospace_assignment\94_2022_6.tif
# Processed image 6738: prospace_assignment\94_2022_7.tif
# Processed image 6739: prospace_assignment\94_2022_8.tif
# Processed image 6740: prospace_assignment\94_2022_9.tif
# Processed image 6741: prospace_assignment\94_2023_0.tif
# Processed image 6742: prospace_assignment\94_2023_1.tif
# Processed image 6743: prospace_assignment\94_2023_2.tif
# Processed image 6744: prospace_assignment\94_2023_3.tif
# Processed image 6745: prospace_assignment\95_2022_10.tif
# Processed image 6746: prospace_assignment\95_2022_11.tif
# Processed image 6747: prospace_assignment\95_2022_4.tif
# Processed image 6748: prospace_assignment\95_2022_5.tif
# Processed image 6749: prospace_assignment\95_2022_6.tif
# Processed image 6750: prospace_assignment\95_2022_7.tif
# Processed image 6751: prospace_assignment\95_2022_8.tif
# Processed image 6752: prospace_assignment\95_2022_9.tif
# Processed image 6753: prospace_assignment\95_2023_0.tif
# Processed image 6754: prospace_assignment\95_2023_1.tif
# Processed image 6755: prospace_assignment\95_2023_2.tif
# Processed image 6756: prospace_assignment\95_2023_3.tif
# Processed image 6757: prospace_assignment\96_2022_10.tif
# Processed image 6758: prospace_assignment\96_2022_11.tif
# Processed image 6759: prospace_assignment\96_2022_4.tif
# Processed image 6760: prospace_assignment\96_2022_5.tif
# Processed image 6761: prospace_assignment\96_2022_6.tif
# Processed image 6762: prospace_assignment\96_2022_7.tif
# Processed image 6763: prospace_assignment\96_2022_8.tif
# Processed image 6764: prospace_assignment\96_2022_9.tif
# Processed image 6765: prospace_assignment\96_2023_0.tif
# Processed image 6766: prospace_assignment\96_2023_1.tif
# Processed image 6767: prospace_assignment\96_2023_2.tif
# Processed image 6768: prospace_assignment\96_2023_3.tif
# Processed image 6769: prospace_assignment\97_2022_10.tif
# Processed image 6770: prospace_assignment\97_2022_11.tif
# Processed image 6771: prospace_assignment\97_2022_4.tif
# Processed image 6772: prospace_assignment\97_2022_5.tif
# Processed image 6773: prospace_assignment\97_2022_6.tif
# Processed image 6774: prospace_assignment\97_2022_7.tif
# Processed image 6775: prospace_assignment\97_2022_8.tif
# Processed image 6776: prospace_assignment\97_2022_9.tif
# Processed image 6777: prospace_assignment\97_2023_0.tif
# Processed image 6778: prospace_assignment\97_2023_1.tif
# Processed image 6779: prospace_assignment\97_2023_2.tif
# Processed image 6780: prospace_assignment\97_2023_3.tif
# Processed image 6781: prospace_assignment\98_2022_10.tif
# Processed image 6782: prospace_assignment\98_2022_11.tif
# Processed image 6783: prospace_assignment\98_2022_4.tif
# Processed image 6784: prospace_assignment\98_2022_5.tif
# Processed image 6785: prospace_assignment\98_2022_6.tif
# Processed image 6786: prospace_assignment\98_2022_7.tif
# Processed image 6787: prospace_assignment\98_2022_8.tif
# Processed image 6788: prospace_assignment\98_2022_9.tif
# Processed image 6789: prospace_assignment\98_2023_0.tif
# Processed image 6790: prospace_assignment\98_2023_1.tif
# Processed image 6791: prospace_assignment\98_2023_2.tif
# Processed image 6792: prospace_assignment\98_2023_3.tif
# Processed image 6793: prospace_assignment\99_2022_10.tif
# Processed image 6794: prospace_assignment\99_2022_11.tif
# Processed image 6795: prospace_assignment\99_2022_4.tif
# Processed image 6796: prospace_assignment\99_2022_5.tif
# Processed image 6797: prospace_assignment\99_2022_6.tif
# Processed image 6798: prospace_assignment\99_2022_7.tif
# Processed image 6799: prospace_assignment\99_2022_8.tif
# Processed image 6800: prospace_assignment\99_2022_9.tif
# Processed image 6801: prospace_assignment\99_2023_0.tif
# Processed image 6802: prospace_assignment\99_2023_1.tif
# Processed image 6803: prospace_assignment\99_2023_2.tif
# Processed image 6804: prospace_assignment\99_2023_3.tif
# Processed image 6805: prospace_assignment\9_2022_10.tif
# Processed image 6806: prospace_assignment\9_2022_11.tif
# Processed image 6807: prospace_assignment\9_2022_4.tif
# Processed image 6808: prospace_assignment\9_2022_5.tif
# Processed image 6809: prospace_assignment\9_2022_6.tif
# Processed image 6810: prospace_assignment\9_2022_7.tif
# Processed image 6811: prospace_assignment\9_2022_8.tif
# Processed image 6812: prospace_assignment\9_2022_9.tif
# Processed image 6813: prospace_assignment\9_2023_0.tif
# Processed image 6814: prospace_assignment\9_2023_1.tif
# Processed image 6815: prospace_assignment\9_2023_2.tif
# Processed image 6816: prospace_assignment\9_2023_3.tif

# %% [raw]
# import matplotlib.pyplot as plt
# import random
#
# # Assuming 'dataset' contains your loaded images
# # Convert TensorFlow dataset to NumPy arrays
# numpy_images = [image.numpy() for image in dataset]
#
# # Randomly sample 20 images
# random_images = random.sample(numpy_images, k=20)
#
# # Plot the randomly sampled images
# plt.figure(figsize=(12, 6))
# for i in range(20):
#     plt.subplot(4, 5, i + 1)
#     plt.imshow(random_images[i])
#     plt.axis('off')
# plt.tight_layout()
# plt.show()

# %%
import os
import numpy as np
from PIL import Image
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

def load_and_preprocess_image(file_path, target_size=(64, 64)):
    try:
        # Load TIFF image using Pillow (PIL)
        image = Image.open(file_path)
        # Resize to target size and convert to RGB
        image = image.resize(target_size)
        image = image.convert("RGB")
        # Convert image to numpy array and normalize
        image_array = np.array(image) / 255.0  # Normalize pixel values
        return image_array.flatten()  # Return flattened array
    except Exception as e:
        print(f"Error loading image {file_path}: {e}")
        return None

def load_tiff_dataset(directory):
    file_paths = [os.path.join(directory, file) for file in os.listdir(directory) if file.endswith('.tif')]
    images = [load_and_preprocess_image(file) for file in file_paths]
    # Filter out None values (invalid images)
    images = [img for img in images if img is not None]
    return images

# Example usage
data_directory = 'prospace_assignment'
images_list = load_tiff_dataset(data_directory)

# Shuffle the dataset
shuffled_images = shuffle(images_list, random_state=42)

# Split the dataset into 100 sub datasets
num_subsets = 100
subset_size = len(shuffled_images) // num_subsets

for i in range(num_subsets):
    subset_start = i * subset_size
    subset_end = (i + 1) * subset_size if i < num_subsets - 1 else len(shuffled_images)
    subset_images = shuffled_images[subset_start:subset_end]

    # Perform clustering on the subset
    num_clusters = 3  # Define the number of clusters
    kmeans = KMeans(n_clusters=num_clusters)
    flattened_images = np.array(subset_images)  # Already flattened in loading function
    cluster_labels = kmeans.fit_predict(flattened_images)

    # Process cluster labels as needed
    # Example: Save cluster labels or do further analysis

    print(f"Subset {i+1} processed.")
# Out:
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 1 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 2 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 3 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 4 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 5 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 6 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 7 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 8 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 9 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 10 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 11 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 12 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 13 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 14 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 15 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 16 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 17 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 18 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 19 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 20 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 21 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 22 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 23 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 24 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 25 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 26 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 27 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 28 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 29 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 30 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 31 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 32 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 33 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 34 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 35 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 36 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 37 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 38 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 39 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 40 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 41 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 42 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 43 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 44 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 45 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 46 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 47 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 48 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 49 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 50 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 51 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 52 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 53 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 54 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 55 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 56 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 57 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 58 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 59 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 60 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 61 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 62 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 63 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 64 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 65 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 66 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 67 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 68 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 69 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 70 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 71 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 72 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 73 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 74 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 75 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 76 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 77 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 78 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 79 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 80 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 81 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 82 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 83 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 84 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 85 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 86 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 87 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 88 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 89 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 90 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 91 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 92 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 93 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 94 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 95 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 96 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 97 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 98 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 99 processed.
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\rahul\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Subset 100 processed.
